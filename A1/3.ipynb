# %%
# !git clone https://github.com/surajdx/InformerData.git
# Out:
# Cloning into 'InformerData'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 49 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (49/49), 4.83 MiB | 5.37 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd InformerData
# Out:
# /content/InformerData

# %% [markdown]
# #[Q.3] Multivariate LSTF
# Train the informer model on multivariate data.
#
# Plot and compare the test results with Table (2) in the paper.
#
# Compare your results with the univariate version on the test-set.

# %% [markdown]
# #Ans. Train the informer model.

# %%
# !python -u main_informer.py --model informer --data ETTh1 --attn prob --freq h --do_predict --pred_len 96
# Out:
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=True, mix=True, cols=None, num_workers=0, itr=2, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.5513225
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
setting = 'informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0'

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')


# [samples, pred_len, dimensions]
preds.shape, trues.shape

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# !python -u main_informer.py --model informer --data ETTh2 --attn prob --freq h --do_predict --pred_len 96
# Out:
# Args in experiment:
# Namespace(model='informer', data='ETTh2', root_path='./data/ETT/', data_path='ETTh2.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=True, mix=True, cols=None, num_workers=0, itr=2, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh2_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.2985080
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
setting = 'informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0'

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')


# [samples, pred_len, dimensions]
preds.shape, trues.shape

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# !python -u main_informer.py --model informer --data ETTm1 --attn prob --freq h --do_predict --pred_len 96
# Out:
# Args in experiment:
# Namespace(model='informer', data='ETTm1', root_path='./data/ETT/', data_path='ETTm1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=True, mix=True, cols=None, num_workers=0, itr=2, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTm1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 34369
# val 11425
# test 11425
# 	iters: 100, epoch: 1 | loss: 0.3945279
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
setting = 'informer_ETTm1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0'

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')


# [samples, pred_len, dimensions]
preds.shape, trues.shape

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %% [markdown]
# The values of MSE and MAE are similar to that of in the paper figure 2 with minor differences.

# %% [markdown]
# Comparision between Univariate and Multivariate pridictions.

# %%
# !python -u main_informer.py --model informer --data ETTh1 --attn prob --freq h --do_predict --pred_len 96 --features S
# Out:
# Args in experiment:
# Namespace(model='informer', data='ETTh1', root_path='./data/ETT/', data_path='ETTh1.csv', features='S', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, enc_in=1, dec_in=1, c_out=1, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=5, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=True, mix=True, cols=None, num_workers=0, itr=2, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.2225631
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
setting = 'informer_ETTh1_ftM_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0'

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')


# [samples, pred_len, dimensions]
preds.shape, trues.shape

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

plt.figure()
plt.title('Multivariate LSTF')
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

setting = 'informer_ETTh1_ftS_sl96_ll48_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0'

preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')


# [samples, pred_len, dimensions]
preds.shape, trues.shape

prediction = np.load('./results/'+setting+'/real_prediction.npy')

prediction.shape

plt.figure()
plt.title('Univariate LSTF')
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()
